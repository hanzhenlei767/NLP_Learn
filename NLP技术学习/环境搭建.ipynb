# %% [markdown]
# # 1. Anaconda安装及使用

# %% [markdown]
# ## 1.1 Anaconda 安装

# %% [markdown]
# * 1.百度关键词搜索或者直接手撸网址，找到官网https://www.anaconda.com/
# * 2.找到anaconda出品中的安装文件下载处单击进去：
# ![1.png](attachment:1.png)
# * 3.可选择适合自己电脑的系统（windows,mac，linux）,python版本（python3，python2），多少位的系统（32位，64位）
# ![2.png](attachment:2.png)

# %% [markdown]
# ## 1.2 Anaconda 使用

# %% [markdown]
# * 1.打开Anaconda的命令提示窗：
# ![3.png](attachment:3.png)
# * 2.可以通过pip install tensorflow方式安装所需要的包
# * 3.修改jupyter notebook的启动路径，请参见博客：https://blog.csdn.net/hhl_csdn/article/details/68950917

# %% [markdown]
# ## 1.3 jupyter notebook 使用

# %% [markdown]
# 使用说明：https://cloud.tencent.com/developer/news/323834

# %% [markdown]
# ## 1.4 MarkDown 使用

# %% [markdown]
# * 1.Markdown数学公式语法:https://www.jianshu.com/p/e74eb43960a1
# * 2.Markdown公式编辑使用方法：https://www.cnblogs.com/q735613050/p/7253073.html
# * 3.Markdown公式编辑器：http://latex.codecogs.com/eqneditor/editor.php

# %% [markdown]
# # 2. PyCharm安装及使用

# %% [markdown]
# ## 2.1  PyCharm的安装

# %% [markdown]
# * 1.百度关键词搜索或者直接手撸网址，找到官网:https://www.jetbrains.com/zh/pycharm/specials/pycharm/pycharm.html?utm_source=baidu&utm_medium=cpc&utm_campaign=cn-bai-br-pycharm-ph-pc&utm_content=pycharm-pure&utm_term=pycharm&gclid=CIz0xuzXvOECFYYAXAod0SoGXA&gclsrc=ds
# ![5.png](attachment:5.png)
# * 2.直接点击下载：
# ![6.png](attachment:6.png)
# * 3.设置anaconda的环境目录和pycharm的环境目录一致，这样同一包只需要安装一遍，两种环境可以共享。
